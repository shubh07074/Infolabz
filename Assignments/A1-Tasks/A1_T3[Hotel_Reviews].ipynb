# %% [markdown]
# # 1) print total number of rows, 2) print total number of cols ,3) print name of all columns ,4) print only reviews column, 5) check null ( true false ),6) Allow user to insert hotel name. If hotel not found print No hotel found in database. If found print bar graph of rating count of that hotel.

# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# loading the data
data = pd.read_csv("hotel.csv")
data.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWE2FvX5RxPSIh2RscTK  2018-01-18T18:43:12Z  2019-05-20T23:55:47Z
# 1  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 2  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 3  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 4  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
#
#                           address  \
# 0                 5620 Calle Real
# 1  5th And San Carlos PO Box 3574
# 2  5th And San Carlos PO Box 3574
# 3  5th And San Carlos PO Box 3574
# 4  5th And San Carlos PO Box 3574
#
#                                           categories  \
# 0  Hotels,Hotels and motels,Hotel and motel mgmt....
# 1                               Hotels,Lodging,Hotel
# 2                               Hotels,Lodging,Hotel
# 3                               Hotels,Lodging,Hotel
# 4                               Hotels,Lodging,Hotel
#
# ...

# %%
# 1.print total number of rows
print(len(data))
# Out:
# 10000

# %%
# 2.print total number of cols
print(len(data.columns))
# Out:
# 26

# %%
# 3.print name of all columns
for i in data.columns:
  print(i)
# Out:
# id
# dateAdded
# dateUpdated
# address
# categories
# primaryCategories
# city
# country
# keys
# latitude
# longitude
# name
# postalCode
# province
# reviews.date
# reviews.dateAdded
# reviews.dateSeen
# reviews.rating
# reviews.sourceURLs
# reviews.text
# reviews.title
# reviews.userCity
# reviews.userProvince
# reviews.username
# sourceURLs
# websites

# %%
# 4.print only reviews column
data.iloc[:,14:24]
# Out:
#                   reviews.date  reviews.dateAdded  \
# 0     2018-01-01T00:00:00.000Z                NaN
# 1         2016-04-02T00:00:00Z                NaN
# 2         2016-01-06T00:00:00Z                NaN
# 3         2016-08-22T00:00:00Z                NaN
# 4         2016-03-21T00:00:00Z                NaN
# ...                        ...                ...
# 9995      2015-12-24T00:00:00Z                NaN
# 9996      2015-11-17T00:00:00Z                NaN
# 9997      2016-07-06T00:00:00Z                NaN
# 9998  2016-10-26T00:00:00.000Z                NaN
# 9999  2017-06-29T00:00:00.000Z                NaN
#
#                                        reviews.dateSeen  reviews.rating  \
# 0                                  2018-01-03T00:00:00Z               3
# 1                                  2016-10-09T00:00:00Z               4
# 2                                  2016-10-09T00:00:00Z               3
# ...

# %%
# 5.check null ( true false )
data.isnull()
# Out:
#          id  dateAdded  dateUpdated  address  categories  primaryCategories  \
# 0     False      False        False    False       False              False
# 1     False      False        False    False       False              False
# 2     False      False        False    False       False              False
# 3     False      False        False    False       False              False
# 4     False      False        False    False       False              False
# ...     ...        ...          ...      ...         ...                ...
# 9995  False      False        False    False       False              False
# 9996  False      False        False    False       False              False
# 9997  False      False        False    False       False              False
# 9998  False      False        False    False       False              False
# 9999  False      False        False    False       False              False
#
# ...

# %%
data.isnull().sum()
# Out:
# id                          0
# dateAdded                   0
# dateUpdated                 0
# address                     0
# categories                  0
# primaryCategories           0
# city                        0
# country                     0
# keys                        0
# latitude                    0
# longitude                   0
# name                        0
# postalCode                  0
# province                    0
# reviews.date                0
# reviews.dateAdded       10000
# reviews.dateSeen            0
# reviews.rating              0
# reviews.sourceURLs          0
# reviews.text                0
# reviews.title               1
# reviews.userCity            0
# reviews.userProvince        2
# reviews.username            0
# sourceURLs                  0
# websites                    0
# dtype: int64

# %%
# 6.Allow user to insert hotel name.If hotel not found print No hotel found in database. If found print bar graph of rating count of that hotel.
Hotel = input("Enter the Hotel Name: ")
if Hotel in data['name'].values:
    hotel_data = data[data['name'] == Hotel]
    rating_counts = hotel_data['reviews.rating'].value_counts()
    plt.bar(rating_counts.index, rating_counts.values)
    plt.xlabel('Rating')
    plt.ylabel('Count')
    plt.title(f'Rating Count for {Hotel}')
    plt.show()
else:
    print("No hotel found in database")
