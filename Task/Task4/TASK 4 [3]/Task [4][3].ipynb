# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
data = pd.DataFrame(np.hstack((X, y)), columns=['X', 'y'])

# %%
data.head()
# Out:
#           X          y
# 0  1.231255   9.019765
# 1  1.322851   8.593312
# 2  0.021339   2.559179
# 3  0.542139   4.550066
# 4  1.703780  12.555489

# %%
model = LinearRegression()

# %%
model.fit(data[['X']],data[['y']])
# Out:
# LinearRegression()

# %%
X_new = np.linspace(0, 2, 100).reshape(100, 1)
y_pred = model.predict(X_new)
# Out:
# C:\Users\Shubham\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(data['X'], data['y'], label='Data')
plt.plot(X_new, y_pred, color='r', label='Prediction Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression with Dummy Data')
plt.legend()
plt.show()
